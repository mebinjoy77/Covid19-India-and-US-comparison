# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('owid-covid-data.csv')

# %%
data.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba  2020-03-21          NaN        NaN
# 4      ABW  North America    Aruba  2020-03-22          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           NaN         0.0                  0.0  ...
# 3               0.286           NaN         NaN                  0.0  ...
# 4               0.286           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
data.fillna(0,inplace=True)

# %%
data.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          0.0        0.0
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba  2020-03-21          0.0        0.0
# 4      ABW  North America    Aruba  2020-03-22          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0               0.000           0.0         0.0                  0.0  ...
# 1               0.286           0.0         0.0                  0.0  ...
# 2               0.286           0.0         0.0                  0.0  ...
# 3               0.286           0.0         0.0                  0.0  ...
# 4               0.286           0.0         0.0                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
s = data[data['location'] == 'India']
s['date']
u =  data[data['location'] == 'United States']
u
# Out:
#       iso_code      continent       location        date  total_cases  \
# 50979      USA  North America  United States  2019-12-31          NaN
# 50980      USA  North America  United States  2020-01-01          NaN
# 50981      USA  North America  United States  2020-01-02          NaN
# 50982      USA  North America  United States  2020-01-03          NaN
# 50983      USA  North America  United States  2020-01-04          NaN
# ...        ...            ...            ...         ...          ...
# 51285      USA  North America  United States  2020-11-01    9126361.0
# 51286      USA  North America  United States  2020-11-02    9207362.0
# 51287      USA  North America  United States  2020-11-03    9291245.0
# 51288      USA  North America  United States  2020-11-04    9383979.0
# 51289      USA  North America  United States  2020-11-05    9486486.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
x = s['date']
y = s['total_cases']
plt.plot(x,y)
x2 = u['date']
y2 = u['total_cases']
dt = u['date'].tolist()
plt.plot(x2,y2)
plt.title('Covid 19 Cases Comparison India and US')
plt.xlabel('Months')
plt.ylabel('No of Covid Cases in Thousands')
plt.legend(['India','US'])
plt.xticks(x,dt)
plt.savefig('IndUSCovid.jpg')

# %% [markdown]
# This is the comparison of Covid Cases in India and the US

# %% [markdown]
# Now let's look at the average cases in these both countries

# %%
print('US Average Cases per day -  ',u['new_cases'].mean())
print('India Average Cases per day - ',s['new_cases'].mean())
# Out:
# US Average Cases per day -   30503.17041800643
# India Average Cases per day -  26980.92258064516

# %% [markdown]
# Now let's look at the maximum cases that was recorded in both countries

# %%
print('US Maximum Cases reported per day -  ',u['new_cases'].max())
print('India Maximum Cases reported per day - ',s['new_cases'].max())
# Out:
# US Maximum Cases reported per day -   102507.0
# India Maximum Cases reported per day -  97894.0

# %% [markdown]
# Note that this data is as of until 05/11/2020
